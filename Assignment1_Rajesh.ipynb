# %% [markdown]
# # Task1:

# %%
#Screenshot of Juptyer Notebook

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Program to find the range(2000,3200) of number which is divisible by 7 and not a multiple of 5
n1=[]
for x in range(2000,3200):
    if (x%7 == 0):
        n1.append(str(x))
    while(x > 0):
        x = x -5
        if (x != 0):
           #n1.append(str(x))
            break
print (','.join(n1))
# Out:
# 2002,2009,2016,2023,2030,2037,2044,2051,2058,2065,2072,2079,2086,2093,2100,2107,2114,2121,2128,2135,2142,2149,2156,2163,2170,2177,2184,2191,2198,2205,2212,2219,2226,2233,2240,2247,2254,2261,2268,2275,2282,2289,2296,2303,2310,2317,2324,2331,2338,2345,2352,2359,2366,2373,2380,2387,2394,2401,2408,2415,2422,2429,2436,2443,2450,2457,2464,2471,2478,2485,2492,2499,2506,2513,2520,2527,2534,2541,2548,2555,2562,2569,2576,2583,2590,2597,2604,2611,2618,2625,2632,2639,2646,2653,2660,2667,2674,2681,2688,2695,2702,2709,2716,2723,2730,2737,2744,2751,2758,2765,2772,2779,2786,2793,2800,2807,2814,2821,2828,2835,2842,2849,2856,2863,2870,2877,2884,2891,2898,2905,2912,2919,2926,2933,2940,2947,2954,2961,2968,2975,2982,2989,2996,3003,3010,3017,3024,3031,3038,3045,3052,3059,3066,3073,3080,3087,3094,3101,3108,3115,3122,3129,3136,3143,3150,3157,3164,3171,3178,3185,3192,3199

# %%
#Print the first name and Last name in reverse order
fstname= input("please type your firstname ")
lstname = input("please type your lastname ")
print ("Your First Name & Last Name in reverse Order  " + fstname [: : -1] + "  " + lstname[: : -1] + " ")
# Out:
# please type your firstname Rajesh
# please type your lastname Raghavan
# Your First Name & Last Name in reverse Order  hsejaR  navahgaR

# %%
#Program to find the volume of a sphere with a diameter 12cm
Diameter=12
v = (4/3)*3.14*(Diameter/2)**3
#pi = 3.141
#c = 4/3
#v = c*3.14*radius
print(v)
# Out:
# 904.3199999999999

# %% [markdown]
# # Task2:

# %%
#Program to accept the sequence of comma separated number from console and generate List
n=[] #intialize empty list
n = input("type list number by comman separated ")
for i in n:
    print(i,end="")
# Out:
# type list number by comman separated 1,2,3,4
# 1,2,3,4

# %%
# Function to demonstrate printing pattern 
n=5
for i in range(0, n): 
    for j in range(0, i+1): 
                # printing stars 
        #print(i)
        print("* ",end="") 
    print("\r")
    a =n-1
for i in range(n):   
        for k in range(a-i):
            print("* ",end="") 
            #print(k)
        print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
#Progam to reverse word after accepting the input from user
word= input("Input Word: ")
print ("Output: " + word [: : -1])
# Out:
# Input Word: AcadGild
# Output: dliGdacA

# %%
#Program to print the give string in the format specified 
print("WE, THE PEOPLE OF INDIA,\n      having solemnly resolved to constitute India into a SOVEREIGN,\n             SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC\n              and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
#       having solemnly resolved to constitute India into a SOVEREIGN,
#              SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#               and to secure to all its citizens
